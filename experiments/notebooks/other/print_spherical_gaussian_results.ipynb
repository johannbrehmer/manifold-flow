# %% [markdown]
# # Spherical Gaussian experiment: generative results

# %% [markdown]
# ## Setup

# %%
import sys
import numpy as np
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ## Load results

# %%
setup_filenames = [
    "2_3_0.010",
    "2_3_0.001",
    "2_3_0.100",
]
setup_labels = [
    "epsilon = 0.01",
    "epsilon = 0.001",
    "epsilon = 0.1",
]
n_runs = 3

# %%
algo_filenames = []
algo_additionals = []
algo_labels = []
algo_dividers = []

def add_algo(filename, add, label):
    algo_filenames.append(filename)
    algo_additionals.append(add)
    algo_labels.append(label)
    
    
def add_divider():
    algo_dividers.append(len(algo_filenames))
    
    
add_divider()
add_algo("flow", "_small", "Flow")
add_algo("flow", "_small_long", "Flow (long)")
add_algo("flow", "_small_shallow_long", "Flow (shallow, long)")

add_divider()
add_algo("mf_specified", "_small", "MF") 
add_algo("mf_specified", "_small_long", "MF (long)") 
add_algo("mf_specified", "_small_shallow_long", "MF (shallow, long)")

add_divider()
add_algo("gamf_specified", "_small_largebs", "MF-A")
add_algo("gamf_specified", "_small_hugebs", "MF-A (5k batchsize)") 
add_algo("gamf_specified", "_small_largebs_long", "MF-A (long)") 
add_algo("gamf_specified", "_small_largebs_shallow_long", "MF-A (shallow, long)") 

# add_algo("pie_specified", "_small", "Prescr. PIE") 
# add_algo("pie_specified", "_small_long", "Prescr. PIE (long)") 
# add_algo("pie_specified", "_small_shallow_long", "Prescr. PIE (shallow, long)") 

add_divider()
add_algo("pie", "_small", "PIE") 
# add_algo("pie", "_small_pieepsilon03", "PIE (ε = 0.3)") 
# add_algo("pie", "_small_pieepsilon01", "PIE (ε = 0.1)") 
# add_algo("pie", "_small_pieepsilon003", "PIE (ε = 0.03)") 
# add_algo("pie", "_small_pieepsilon0003", "PIE (ε = 0.003)") 
# add_algo("pie", "_small_pieepsilon0001", "PIE (ε = 0.001)") 
add_algo("pie", "_small_long", "PIE (long)") 
add_algo("pie", "_small_shallow_long", "PIE (shallow, long)") 

add_divider()
add_algo("mf", "_small", "MLF")
add_algo("mf", "_small_noprepost", "MLF (no pre/post)")
add_algo("mf", "_small_complex", "MLF (complex)") 
add_algo("mf", "_small_prepie", "MLF (pre-PIE)")
add_algo("mf", "_small_prepie_long", "MLF (pre-PIE, long)")
add_algo("mf", "_small_morenll", "MLF (NLL-heavy)")
add_algo("mf", "_small_morenll_long", "MLF (NLL-heavy, long)")
add_algo("mf", "_small_long", "MLF (long)")
add_algo("mf", "_small_shallow_long", "MLF (shallow, long)")

add_divider()
add_algo("emf", "_small", "MLF-E")
add_algo("emf", "_small_long", "MLF-E (long)")
add_algo("emf", "_small_shallow_long", "MLF-E (shallow, long)")

add_divider()
add_algo("gamf", "_small_largebs", "MLF-A")
add_algo("gamf", "_small_hugebs", "MLF-A (5k batchsize)") 
add_algo("gamf", "_small_largebs_long", "MLF-A (long)") 
add_algo("gamf", "_small_largebs_shallow_long", "MLF-A (shallow, long)")

# %%
def load(name, shape, numpyfy=True, result_dir="../data/results"):
    all_results = []
    
    for algo_filename, algo_add in zip(algo_filenames, algo_additionals):
        algo_results = []
        
        for setup_filename in setup_filenames:
            run_results = []
            
            for run in range(3):
                run_str = "" if run == 0 else "_run{}".format(run)
                try:
                    run_results.append(np.load(
                        "{}/{}_2_spherical_gaussian_{}{}{}_{}.npy".format(
                            result_dir, algo_filename, setup_filename, algo_add, run_str, name
                        )
                    ))
                except FileNotFoundError as e:
                    print(e)
                    if shape is None:
                        run_results.append(None)
                    else:
                        run_results.append(np.nan*np.ones(shape))
                        
            algo_results.append(run_results)
            
        all_results.append(algo_results)
    
    return np.asarray(all_results) if numpyfy else all_results


model_gen_x = load("samples", None, numpyfy=False)
model_gen_logp = load("samples_likelihood", (10000,))
model_gen_distance = load("samples_manifold_distance", (10000,))
model_test_log_likelihood = load("model_log_likelihood_test", (1000,))
model_test_reco_error = load("model_reco_error_test", (1000,))
model_ood_log_likelihood = load("model_log_likelihood_ood", (1000,))
model_ood_reco_error = load("model_reco_error_ood", (1000,))
# Out:
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run1_samples.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run2_samples.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run1_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run2_samples_likelihood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run1_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run2_samples_manifold_distance.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run1_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run2_model_log_likelihood_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run1_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run2_model_reco_error_test.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run1_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run2_model_log_likelihood_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.010_small_morenll_long_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.001_small_morenll_long_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/mf_2_spherical_gaussian_2_3_0.100_small_morenll_long_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_long_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_long_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_long_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.010_small_shallow_long_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.001_small_shallow_long_run2_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run1_model_reco_error_ood.npy'
# [Errno 2] No such file or directory: '../data/results/emf_2_spherical_gaussian_2_3_0.100_small_shallow_long_run2_model_reco_error_ood.npy'

# %%
def load_truth(name, samples=True):
    if samples:
        return np.asarray([
            [
                np.load("../data/samples/spherical_gaussian/spherical_gaussian_{}_{}{}.npy".format(
                    setup_filename, name, run_str
                ))
                for run_str in [""] + ["_run{}".format(i) for i in range(1, n_runs)]
            ]
            for setup_filename in setup_filenames
        ])
    else:
        return np.asarray([
            [
                np.load("../data/results/truth_spherical_gaussian_{}{}_{}.npy".format(
                    setup_filename, run_str, name
                ))
                for run_str in [""] + ["_run{}".format(i) for i in range(1, n_runs)]
            ]
            for setup_filename in setup_filenames
        ])


test_x = load_truth("x_test", True)
test_distance = np.abs(np.sum(test_x**2, axis=-1)**0.5 - 1.)
test_logp = load_truth("true_log_likelihood_test", False)

# %% [markdown]
# ## Calculate metrics

# %%
min_logp = -100.
max_distance = 10.

model_gen_mean_logp = np.mean(np.clip(model_gen_logp, min_logp, None), axis=3)
model_gen_mean_distance = np.mean(np.clip(model_gen_distance, None, max_distance), axis=3)

test_mean_logp = np.mean(np.clip(test_logp, min_logp, None), axis=2)
test_mean_distance = np.mean(np.clip(test_distance, None, max_distance), axis=2)

# %%
def calculate_roc_auc(x0, x1):
    assert x0.shape == x1.shape
    old_shape = x0.shape[:-1]
    x0 = x0.reshape(-1, x0.shape[-1])
    x1 = x1.reshape(-1, x0.shape[-1])
    
    aucs = []
    for x0_, x1_ in zip(x0, x1):
        if not np.all(np.isfinite(np.hstack((x0_, x1_)))):
            aucs.append(np.nan)
            continue
            
        auc = roc_auc_score(
            np.hstack((np.zeros(x0_.shape[0], dtype=np.int), np.ones(x1_.shape[0], dtype=np.int))),
            np.hstack((x0_, x1_)),
        )
        auc_flipped = roc_auc_score(
            np.hstack((np.zeros(x0_.shape[0], dtype=np.int), np.ones(x1_.shape[0], dtype=np.int))),
            - np.hstack((x0_, x1_)),
        )
        aucs.append(max(auc, auc_flipped))
        
    aucs = np.asarray(aucs).reshape(old_shape)
    return aucs


model_auc_logp = calculate_roc_auc(model_test_log_likelihood, model_ood_log_likelihood)
model_auc_err = calculate_roc_auc(model_test_reco_error, model_ood_reco_error)
model_auc_use_err = (model_auc_err > model_auc_logp)
model_auc = np.maximum(model_auc_err, model_auc_logp)
# Out:
# /Users/johannbrehmer/anaconda3/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in greater

# %% [markdown]
# ## Print metrics

# %%
def print_results(include_err=False, include_n_runs=False, l_label=max([len(l) for l in algo_labels]), l_mean=6, l_err=4):
    # How to format the numbers
    l_result = l_mean + int(include_err) * (3 + l_err) + int(include_n_runs) * 4
    l_setup = l_result * 3 + 5
    l_total = l_label + 3 * l_setup + 1
    
    def _f(val):
        if not np.any(np.isfinite(val)):
            return " "*l_result
        
        result = "{:>{}.{}f}".format(np.nanmean(val), l_mean, l_mean - 4)
        if include_err:
            result += " ({:>{}.{}f})".format(np.nanstd(val), l_err, l_err - 2)
        if include_n_runs:
            result += " [{:1n}]".format(np.sum(np.isfinite(val)))
        return result
        
    
    # Header
    print(
        "{2:<{0}.{0}s} | {3:^{1}.{1}s} | {4:^{1}.{1}s} | {5:^{1}.{1}s}".format(
            l_label, l_setup - 3, "", setup_labels[0], setup_labels[1], setup_labels[2]
        )
    )
    print(
        "{2:<{0}.{0}s} | {3:>{1}.{1}s} {4:>{1}.{1}s} {5:>{1}.{1}} | {3:>{1}.{1}s} {4:>{1}.{1}s} {5:>{1}.{1}} | {3:>{1}.{1}s} {4:>{1}.{1}s} {5:>{1}.{1}}".format(
            l_label, l_result, "", "Log p", "Dist", "AUC"
        )
    )
    print("-"*l_total)

    # Iterate over methods
    for i, (label, logp, dist, auc) in enumerate(zip(
        ["Simulator"] + algo_labels,
        [test_mean_logp] + list(model_gen_mean_logp),
        [test_mean_distance] + list(model_gen_mean_distance),
        [np.nan * np.zeros(model_auc[0].shape)] + list(model_auc)
    )):
        # Divider
        if i-1 in algo_dividers:
            print("-"*l_total)
            
        # Print results
        print(
            "{1:<{0}.{0}s} | {2} {3} {4} | {5} {6} {7} | {8} {9} {10}".format(
                l_label,
                label,
                _f(logp[0]), _f(dist[0]),  _f(auc[0]),
                _f(logp[1]), _f(dist[1]),  _f(auc[1]),
                _f(logp[2]), _f(dist[2]),  _f(auc[2]), 
            )
        )

# %%
print_results()
# Out:
#                       |    epsilon = 0.01    |   epsilon = 0.001    |    epsilon = 0.1
#                       |  Log p   Dist    AUC |  Log p   Dist    AUC |  Log p   Dist    AUC
# -------------------------------------------------------------------------------------------
# Simulator             |   2.43   0.01        |   4.73   0.00        |   0.09   0.08
# -------------------------------------------------------------------------------------------
# Flow                  |   1.44   0.03   0.70 |   3.10   0.03   0.72 |  -0.83   0.10   0.65
# Flow (long)           |   1.46   0.03   0.69 |   3.20   0.03   0.70 |  -0.76   0.10   0.64
# Flow (shallow, long)  |   1.45   0.03   0.70 |   2.78   0.03   0.69 |  -0.82   0.10   0.64
# -------------------------------------------------------------------------------------------
# MF                    |   2.96   0.00   0.74 |   5.28   0.00   0.73 |   0.65   0.00   0.73
# MF (long)             |   2.95   0.00   0.74 |   5.25   0.00   0.73 |   0.64   0.00   0.73
# MF (shallow, long)    |   2.97   0.00   0.74 |   4.98   0.00   0.73 |   0.67   0.00   0.73
# -------------------------------------------------------------------------------------------
# MF-A                  |   2.88   0.00   0.73 |   5.25   0.00   0.73 |   0.62   0.00   0.73
# MF-A (5k batchsize)   |   2.96   0.00   0.74 |   5.23   0.00   0.73 |   0.63   0.00   0.73
# MF-A (long)           |   2.94   0.00   0.74 |   5.25   0.00   0.73 |   0.62   0.00   0.73
# MF-A (shallow, long)  |   1.96   0.00   0.74 |   5.24   0.00   0.73 |   0.44   0.00   0.73
# -------------------------------------------------------------------------------------------
# PIE                   |   1.00   0.03   0.70 |   0.60   0.02   0.68 |   0.13   0.07   0.65
# PIE (long)            |   2.37   0.02   0.70 |   4.28   0.02   0.69 |  -0.87   0.10   0.66
# PIE (shallow, long)   |  -2.23   0.03   0.69 | -21.82   0.03   0.66 |  -1.01   0.13   0.64
# -------------------------------------------------------------------------------------------
# MLF                   |  -5.42   0.04   0.62 | -37.40   0.07   0.56 |  -0.82   0.10   0.63
# MLF (no pre/post)     | -17.77   0.17   0.63 |  -1.59   0.03   0.57 |  -2.76   0.15   0.62
# MLF (complex)         | -29.22   0.09   0.58 | -27.41   0.07   0.55 |  -0.22   0.04   0.71
# MLF (pre-PIE)         |  -3.49   0.04   0.60 | -16.52   0.03   0.54 |  -0.64   0.07   0.66
# MLF (pre-PIE, long)   | -27.55   0.10   0.63 |  -6.32   0.02   0.57 |  -2.17   0.11   0.68
# MLF (NLL-heavy)       | -29.97   0.15   0.54 | -64.75   0.09   0.52 |
# MLF (NLL-heavy, long) |                      |                      |
# MLF (long)            | -15.94   0.06   0.61 | -49.22   0.08   0.57 |  -7.44   0.30   0.55
# MLF (shallow, long)   | -34.22   0.11   0.55 | -73.10   0.14   0.51 |  -1.73   0.13   0.62
# -------------------------------------------------------------------------------------------
# MLF-E                 |   0.66   0.03   0.63 | -11.96   0.03        |  -1.01   0.14   0.62
# MLF-E (long)          |   2.31   0.02   0.73 | -74.68   0.07   0.52 |  -0.70   0.11   0.50
# MLF-E (shallow, long) | -10.92   0.05   0.54 | -85.28   0.10   0.53 |  -1.48   0.15   0.56
# -------------------------------------------------------------------------------------------
# MLF-A                 |   2.31   0.02   0.57 | -37.95   0.03   0.52 |   0.13   0.05   0.65
# MLF-A (5k batchsize)  |   2.53 (0.02)   0.02 (0.00)   0.62 (0.02) | -33.41 (31.95)   0.02 (0.01)   0.53 (0.01) |   0.01 (0.10)   0.07 (0.01)   0.61 (0.02)
# MLF-A (long)          |  -4.39 (1.66)   0.04 (0.01)   0.51 (0.01) |  -8.54 (0.39)   0.02 (0.00)   0.58 (0.03) |  -0.09 (0.06)   0.08 (0.00)   0.61 (0.03)
# MLF-A (shallow, long) |  -4.07 (5.95)   0.04 (0.01)   0.53 (0.01) | -10.81 (0.88)   0.02 (0.00)   0.57 (0.01) |  -0.11 (0.05)   0.08 (0.00)   0.60 (0.05)

# %%
print_results(include_n_runs=True)
# Out:
#                       |          epsilon = 0.01          |         epsilon = 0.001          |          epsilon = 0.1
#                       |      Log p       Dist        AUC |      Log p       Dist        AUC |      Log p       Dist        AUC
# -------------------------------------------------------------------------------------------------------------------------------
# Simulator             |   2.43 [3]   0.01 [3]            |   4.73 [3]   0.00 [3]            |   0.09 [3]   0.08 [3]
# -------------------------------------------------------------------------------------------------------------------------------
# Flow                  |   1.44 [3]   0.03 [3]   0.70 [3] |   3.10 [3]   0.03 [3]   0.72 [3] |  -0.83 [3]   0.10 [3]   0.65 [3]
# Flow (long)           |   1.46 [3]   0.03 [3]   0.69 [3] |   3.20 [3]   0.03 [3]   0.70 [3] |  -0.76 [3]   0.10 [3]   0.64 [3]
# Flow (shallow, long)  |   1.45 [3]   0.03 [3]   0.70 [3] |   2.78 [3]   0.03 [3]   0.69 [3] |  -0.82 [3]   0.10 [3]   0.64 [3]
# -------------------------------------------------------------------------------------------------------------------------------
# MF                    |   2.96 [3]   0.00 [3]   0.74 [3] |   5.28 [3]   0.00 [3]   0.73 [3] |   0.65 [3]   0.00 [3]   0.73 [3]
# MF (long)             |   2.95 [3]   0.00 [3]   0.74 [3] |   5.25 [3]   0.00 [3]   0.73 [3] |   0.64 [3]   0.00 [3]   0.73 [3]
# MF (shallow, long)    |   2.97 [3]   0.00 [3]   0.74 [3] |   4.98 [3]   0.00 [3]   0.73 [3] |   0.67 [3]   0.00 [3]   0.73 [3]
# -------------------------------------------------------------------------------------------------------------------------------
# MF-A                  |   2.88 [3]   0.00 [3]   0.73 [3] |   5.25 [3]   0.00 [3]   0.73 [3] |   0.62 [3]   0.00 [3]   0.73 [3]
# MF-A (5k batchsize)   |   2.96 [3]   0.00 [3]   0.74 [3] |   5.23 [3]   0.00 [3]   0.73 [3] |   0.63 [3]   0.00 [3]   0.73 [3]
# MF-A (long)           |   2.94 [3]   0.00 [3]   0.74 [3] |   5.25 [3]   0.00 [3]   0.73 [3] |   0.62 [3]   0.00 [3]   0.73 [3]
# MF-A (shallow, long)  |   1.96 [3]   0.00 [2]   0.74 [2] |   5.24 [3]   0.00 [3]   0.73 [3] |   0.44 [3]   0.00 [3]   0.73 [3]
# -------------------------------------------------------------------------------------------------------------------------------
# PIE                   |   1.00 [3]   0.03 [3]   0.70 [3] |   0.60 [3]   0.02 [3]   0.68 [3] |   0.13 [3]   0.07 [3]   0.65 [3]
# PIE (long)            |   2.37 [3]   0.02 [3]   0.70 [3] |   4.28 [3]   0.02 [3]   0.69 [3] |  -0.87 [3]   0.10 [3]   0.66 [3]
# PIE (shallow, long)   |  -2.23 [3]   0.03 [3]   0.69 [3] | -21.82 [3]   0.03 [3]   0.66 [3] |  -1.01 [3]   0.13 [3]   0.64 [3]
# -------------------------------------------------------------------------------------------------------------------------------
