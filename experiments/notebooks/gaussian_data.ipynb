# %%
import numpy as np
import sys
import logging
from matplotlib import pyplot as plt
# %matplotlib inline
import corner

sys.path.append("..")

from generate_gaussian_data import true_logp

# %% [markdown]
# ## Load data

# %%
z = np.load("../data/gaussian/gaussian_8_16_z_test.npy")
x = np.load("../data/gaussian/gaussian_8_16_x_test.npy")
trf = np.load("../data/gaussian/gaussian_transform.npy")
logp = np.load("../data/gaussian/gaussian_8_16_logp_test.npy")

# %%
np.linalg.det(trf)
# Out:
# 5.260217112238395e+106

# %% [markdown]
# ## Plot

# %%
corner.corner(z)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-af6404f5a529> in <module>
# ----> 1 corner.corner(z)
#
# ~/anaconda3/envs/ml/lib/python3.6/site-packages/corner/corner.py in corner(xs, bins, range, weights, color, smooth, smooth1d, labels, label_kwargs, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, hist_kwargs, **hist2d_kwargs)
#     331             hist2d(y, x, ax=ax, range=[range[j], range[i]], weights=weights,
#     332                    color=color, smooth=smooth, bins=[bins[j], bins[i]],
# --> 333                    **hist2d_kwargs)
#     334
#     335             if truths is not None:
#
# ...

# %%
corner.corner(x)

# %% [markdown]
# ## Cross-check log likelihood calculation

# %%
logp_ = true_logp(x, 0.001, 8, 16, trf)

# %%
plt.figure(figsize=(5,5))
plt.scatter(logp_[::100], logp[::100], s=10.)
plt.show()

# %%
np.log(1.e-3)*8
# Out:
# -55.262042231857095
