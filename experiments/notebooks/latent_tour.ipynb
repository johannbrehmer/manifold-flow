# %% [markdown]
# # Latent tour

# %%
# %matplotlib inline

import sys
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import torch
import imageio
from scipy import interpolate

sys.path.append("../../")
from experiments.datasets import FFHQStyleGAN2DLoader
from experiments.architectures.image_transforms import create_image_transform, create_image_encoder
from experiments.architectures.vector_transforms import create_vector_transform
from manifold_flow.flows import ManifoldFlow, EncoderManifoldFlow

# %% [markdown]
# ## Load models

# %%
def load_model(
    filename,
    latentdim=2,
    outerlayers=20,
    innerlayers=6,
    levels=4,
    splinebins=11,
    splinerange=10.0,
    dropout=0.0,
    actnorm=True,
    batchnorm=False,
    contextfeatures=None,
    linlayers=2,
    linchannelfactor=1,
    lineartransform="lu",
):
    steps_per_level = outerlayers // levels
    spline_params = {
        "apply_unconditional_transform": False,
        "min_bin_height": 0.001,
        "min_bin_width": 0.001,
        "min_derivative": 0.001,
        "num_bins": splinebins,
        "tail_bound": splinerange,
    }
    outer_transform = create_image_transform(
        3,
        64,
        64,
        levels=levels,
        hidden_channels=100,
        steps_per_level=steps_per_level,
        num_res_blocks=2,
        alpha=0.05,
        num_bits=8,
        preprocessing="glow",
        dropout_prob=dropout,
        multi_scale=True,
        spline_params=spline_params,
        postprocessing="partial_mlp",
        postprocessing_layers=linlayers,
        postprocessing_channel_factor=linchannelfactor,
        use_actnorm=actnorm,
        use_batchnorm=batchnorm,
    )
    inner_transform = create_vector_transform(
        latentdim,
        innerlayers,
        linear_transform_type=lineartransform,
        base_transform_type="rq-coupling",
        context_features=contextfeatures,
        dropout_probability=dropout,
        tail_bound=splinerange,
        num_bins=splinebins,
        use_batch_norm=batchnorm,
    )
    model = ManifoldFlow(
        data_dim=(3, 64, 64),
        latent_dim=latentdim,
        outer_transform=outer_transform,
        inner_transform=inner_transform,
        apply_context_to_outer=False,
        pie_epsilon=0.1,
        clip_pie=None
    )
        
    model.load_state_dict(
        torch.load("../data/models/{}.pt".format(filename), map_location=torch.device("cpu"))
    )
    _ = model.eval()
    
    return model

# %%
mf2 = load_model("mf_2_gan2d_april")
mf64 = load_model("mf_64_gan64d_april_run1", innerlayers=8, linchannelfactor=2, latentdim=64, contextfeatures=1)

# %% [markdown]
# ## Master function

# %%
def make_tour(model, z_checkpoints, filename, n_frames=200, fps=25, interpolate_dims=10, context=None):
    n_checkpoints = len(z_checkpoints)
    checkpoint_frames = [int(round(i * n_frames / n_checkpoints, 0)) for i in range(n_checkpoints)]
    
    z_fix = z_checkpoints[0, np.newaxis, interpolate_dims:] + np.zeros((n_frames, 1))
    z_checkpoints = np.concatenate((z_checkpoints[:, :interpolate_dims], z_checkpoints[0:1, :interpolate_dims]), axis=0)
    tck, u = interpolate.splprep(z_checkpoints.T, s=0, per=True)
    z_frames = np.array(interpolate.splev(np.linspace(0, 1, n_frames), tck)).T
    z_frames = np.concatenate((z_frames, z_fix), axis=1)
    
    ims = []
    for z in z_frames:
        x = model.decode(torch.tensor(z).to(torch.float).unsqueeze(0), context=context.unsqueeze(0)).squeeze().detach().numpy()
        x = np.transpose(x, [1,2,0])
        ims.append(x)
    
    imageio.mimsave(filename, ims, 'GIF-FI', duration=1.0/fps)

# %% [markdown]
# ## n=2 circle tour

# %%
n_frames = 200

ts = np.linspace(0., 2. * np.pi, n_frames + 1)[:-1]
zs = np.vstack((np.cos(ts), np.sin(ts))).T

make_tour(mf2, zs, n_frames=n_frames, filename="../figures/gan2d_tour_circle_mf.gif")

# %% [markdown]
# ## n=64 tour from a real image

# %%
param = torch.zeros((1,)).to(torch.float)
x_reals = np.array([plt.imread("../data/merle.jpg")])
x_reals_ = torch.tensor(x_reals.transpose(0,3,1,2)).to(torch.float)
z_reals = mf64.encode(x_reals_, context=param.unsqueeze(0)).detach().numpy()
z_reals
# Out:
# array([[-1.2029319 , -1.7852677 ,  1.267674  , -1.4313987 , -0.24781178,
#          1.5943398 ,  0.70669454,  0.51296514,  0.33693933, -0.88983214,
#         -1.9633608 ,  0.5775551 ,  0.45369503, -0.71944   , -1.7163948 ,
#         -0.7424832 ,  2.0496745 ,  0.0384796 ,  0.9369421 , -2.0319183 ,
#         -4.220821  ,  1.6531723 ,  0.4732769 , -0.672833  , -0.9516078 ,
#          2.4319878 , -1.1113434 , -1.1410133 ,  1.4168046 , -2.5789747 ,
#         -2.4077215 , -0.68494076,  1.2116934 , -1.7872741 ,  1.3651558 ,
#         -0.60139227,  0.91517925, -1.2779715 ,  1.2163581 ,  1.5368803 ,
#          0.45496592, -0.94389385,  2.3437946 ,  2.128365  ,  0.06525467,
#         -0.07784646,  1.6460439 , -1.7622306 ,  4.755513  , -0.12985978,
#          0.8114347 ,  0.04490801,  3.2975829 , -0.12547274,  3.7040296 ,
#          0.15134586, -0.9683202 , -0.42259032,  0.9044508 , -0.21217161,
#          1.157878  , -0.13085735,  1.5256104 , -0.93967944]],
#       dtype=float32)

# %%
z_tour = np.array([
    z_reals[0],
    np.random.normal(size=64),
    np.random.normal(size=64),
    np.random.normal(size=64),
])
z_tour[:,:10]
# Out:
# array([[-1.20293188, -1.78526771,  1.26767397, -1.43139875, -0.24781178,
#          1.59433985,  0.70669454,  0.51296514,  0.33693933, -0.88983214],
#        [-2.4200444 , -0.42285216,  0.84097715,  0.16027569, -1.19188345,
#         -0.35780866, -0.00586058,  0.60336087,  1.72084808,  1.31790089],
#        [-1.14084624, -0.73506788, -0.70755633, -1.48814686, -0.33758468,
#          1.94075239,  0.04507095, -0.68679437,  0.26435337,  1.20883743],
#        [ 0.43246569, -0.34514785,  0.45194108, -0.22670406,  1.31825989,
#         -0.64215863,  0.66855823,  0.53808919,  0.15377462,  0.46934764]])

# %%
make_tour(mf64, z_tour, n_frames=200, filename="../figures/merle.gif", context=param)
# Out:
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.643783569335938, 243.88955688476562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.362602233886719, 244.33993530273438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [7.8630828857421875, 244.99459838867188]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [7.157768249511719, 245.77920532226562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [6.667510986328125, 246.48403930664062]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [6.143333435058594, 247.01576232910156]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.8071441650390625, 247.69322204589844]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.5603790283203125, 248.01608276367188]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.4268646240234375, 248.32894897460938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.325157165527344, 248.47714233398438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.089439392089844, 249.0523681640625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.058448791503906, 250.21835327148438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.002288818359375, 251.20791625976562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.80224609375, 252.08309936523438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.423744201660156, 253.30462646484375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.0269012451171875, 253.89161682128906]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.8840103149414062, 254.99765014648438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.8716659545898438, 256.67626953125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.096183776855469, 259.0582275390625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.4276123046875, 260.57904052734375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [2.89825439453125, 262.3839111328125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [2.524078369140625, 264.19647216796875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [2.1407470703125, 265.2133483886719]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [1.5921859741210938, 265.86370849609375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [1.1934890747070312, 266.07098388671875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0.7718048095703125, 266.2271728515625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0.29044342041015625, 266.6160888671875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.2476348876953125, 266.8431396484375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.78948974609375, 267.0042419433594]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.0956573486328125, 266.821044921875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.2106170654296875, 266.2117614746094]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.39990234375, 265.7350769042969]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.394775390625, 265.1480712890625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.290252685546875, 264.10089111328125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.1044464111328125, 262.60906982421875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.909423828125, 262.75579833984375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.851531982421875, 263.40460205078125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.72930908203125, 263.439697265625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.519134521484375, 264.3197021484375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.4281158447265625, 265.38397216796875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.8187103271484375, 266.145263671875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.449676513671875, 267.17205810546875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.889556884765625, 267.55230712890625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-2.214935302734375, 267.0243225097656]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-2.472381591796875, 266.86865234375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-2.7988433837890625, 266.802490234375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-2.95556640625, 266.898193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-3.2626190185546875, 267.1559753417969]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-3.631500244140625, 267.4477844238281]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-3.876922607421875, 267.674072265625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.00689697265625, 267.9185791015625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.142578125, 268.24517822265625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.267242431640625, 268.63018798828125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.3482513427734375, 268.99365234375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.4165191650390625, 269.517333984375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.543548583984375, 271.1518859863281]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.73468017578125, 273.5875244140625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.82177734375, 274.8424072265625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.88702392578125, 275.8460388183594]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.195281982421875, 276.6868896484375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.753814697265625, 277.22540283203125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.27679443359375, 277.99420166015625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.4549407958984375, 278.842041015625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.4333343505859375, 279.8639221191406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.27886962890625, 281.263427734375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.7912750244140625, 282.52215576171875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-7.387298583984375, 283.9296569824219]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-8.046829223632812, 284.9718017578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-8.303558349609375, 285.683349609375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-8.323593139648438, 286.23907470703125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-8.274505615234375, 286.77581787109375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-7.736175537109375, 286.2762756347656]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.885101318359375, 285.66741943359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.8888092041015625, 284.756591796875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.9465179443359375, 283.74285888671875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.95172119140625, 282.693603515625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.7861785888671875, 280.68841552734375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.43975830078125, 279.30206298828125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.0521087646484375, 279.8424377441406]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.829833984375, 281.59716796875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.5838623046875, 283.0699462890625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.3085784912109375, 284.11639404296875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.0979156494140625, 285.23236083984375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.234893798828125, 286.3280944824219]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.5692596435546875, 287.3385925292969]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.805572509765625, 288.3382568359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.99578857421875, 289.5726318359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.1009674072265625, 290.31915283203125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.0860595703125, 290.59454345703125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.9540252685546875, 290.9445495605469]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.818634033203125, 290.95849609375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.796600341796875, 291.32763671875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.8058319091796875, 292.67236328125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.74969482421875, 293.6571044921875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.6533203125, 293.13739013671875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.58502197265625, 292.22412109375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.581787109375, 292.1053466796875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-6.9540557861328125, 292.20648193359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-12.490646362304688, 292.3816833496094]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-14.476242065429688, 292.234619140625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-15.696731567382812, 291.98681640625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-16.396881103515625, 291.93310546875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-16.886077880859375, 292.14569091796875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-17.030487060546875, 292.35491943359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-17.245162963867188, 292.455078125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-17.255569458007812, 292.16094970703125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-17.130294799804688, 291.62371826171875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-16.90625, 290.79443359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-16.569854736328125, 290.10296630859375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-16.354888916015625, 289.4117431640625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-15.849853515625, 288.47003173828125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-15.219802856445312, 287.57672119140625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-14.397750854492188, 286.50494384765625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-19.431121826171875, 285.1651611328125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-22.134170532226562, 284.15032958984375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-13.421600341796875, 284.7507019042969]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-8.016998291015625, 285.03680419921875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-5.96875, 285.4123229980469]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.5786285400390625, 284.63848876953125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.3270416259765625, 283.7208557128906]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-4.029510498046875, 282.39337158203125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-3.678619384765625, 280.7615661621094]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-3.3896636962890625, 278.82061767578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-3.0412445068359375, 275.0391845703125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-2.7284698486328125, 271.91143798828125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-2.3336944580078125, 270.62945556640625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.8316650390625, 269.02734375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.2760772705078125, 267.8202819824219]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.8897247314453125, 265.92559814453125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.6943817138671875, 265.1263427734375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.394989013671875, 264.251953125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.3336181640625, 263.88482666015625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.5921478271484375, 263.3193054199219]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.9115447998046875, 262.97991943359375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.195526123046875, 262.71685791015625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.3724517822265625, 263.1522521972656]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.522369384765625, 263.82037353515625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.6378021240234375, 264.26788330078125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.7323455810546875, 264.37896728515625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.802490234375, 264.5759582519531]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.7631072998046875, 264.63458251953125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.73272705078125, 264.71392822265625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.727081298828125, 264.759033203125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.6845855712890625, 264.65533447265625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.6306610107421875, 264.6031494140625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.423583984375, 264.52557373046875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.330780029296875, 264.65850830078125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.19085693359375, 264.85577392578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-0.8112335205078125, 265.5133056640625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0.22739410400390625, 266.3794860839844]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [1.3997726440429688, 266.7126770019531]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [2.616546630859375, 266.6805419921875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.61676025390625, 266.6726989746094]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.40594482421875, 266.789794921875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.3119735717773438, 266.7257080078125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.3205795288085938, 266.61737060546875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.3986434936523438, 266.3157653808594]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.5971603393554688, 265.70953369140625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.753448486328125, 265.03900146484375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.9550018310546875, 264.4947509765625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.1257476806640625, 263.8438720703125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.375030517578125, 263.3468017578125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.606819152832031, 262.9151611328125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.766021728515625, 262.6375732421875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.812042236328125, 262.34130859375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.944664001464844, 261.509033203125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.196563720703125, 260.307373046875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.696983337402344, 258.86676025390625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [6.450531005859375, 256.7589111328125]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [6.34912109375, 255.12271118164062]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.8781280517578125, 253.81390380859375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.374267578125, 252.7732696533203]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.868003845214844, 252.2718048095703]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.440948486328125, 251.54539489746094]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.524787902832031, 250.8902130126953]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.663551330566406, 250.15464782714844]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.065376281738281, 249.00155639648438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.546653747558594, 248.74771118164062]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [6.2647705078125, 248.58316040039062]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [6.782127380371094, 248.3224334716797]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.572334289550781, 247.744384765625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.576332092285156, 247.09661865234375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.985008239746094, 246.25137329101562]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.94146728515625, 245.11517333984375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [7.191795349121094, 244.06753540039062]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.453857421875, 242.79627990722656]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [9.820724487304688, 241.7264404296875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [11.374000549316406, 241.40701293945312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [12.10791015625, 241.4769287109375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [12.430900573730469, 241.91073608398438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [12.381919860839844, 242.213134765625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [11.944557189941406, 242.3826904296875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [11.459335327148438, 242.55984497070312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [11.362968444824219, 242.61868286132812]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [10.806999206542969, 242.82574462890625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [10.450401306152344, 242.94158935546875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [9.852127075195312, 242.90463256835938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [9.503181457519531, 243.09027099609375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [9.007217407226562, 243.4661865234375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.643783569335938, 243.88955688476562]. Convert image to uint8 prior to saving to suppress this warning.
