# %% [markdown]
# # Latent tour

# %%
# %matplotlib inline

import sys
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import torch
import imageio
from scipy import interpolate

sys.path.append("../../")
from experiments.datasets import FFHQStyleGAN2DLoader
from experiments.architectures.image_transforms import create_image_transform, create_image_encoder
from experiments.architectures.vector_transforms import create_vector_transform
from manifold_flow.flows import ManifoldFlow, EncoderManifoldFlow

# %% [markdown]
# ## Load models

# %%
def load_model(
    filename,
    latentdim=2,
    outerlayers=20,
    innerlayers=6,
    levels=4,
    splinebins=11,
    splinerange=10.0,
    dropout=0.0,
    actnorm=True,
    batchnorm=False,
    contextfeatures=None,
    linlayers=2,
    linchannelfactor=1,
    lineartransform="lu",
):
    steps_per_level = outerlayers // levels
    spline_params = {
        "apply_unconditional_transform": False,
        "min_bin_height": 0.001,
        "min_bin_width": 0.001,
        "min_derivative": 0.001,
        "num_bins": splinebins,
        "tail_bound": splinerange,
    }
    outer_transform = create_image_transform(
        3,
        64,
        64,
        levels=levels,
        hidden_channels=100,
        steps_per_level=steps_per_level,
        num_res_blocks=2,
        alpha=0.05,
        num_bits=8,
        preprocessing="glow",
        dropout_prob=dropout,
        multi_scale=True,
        spline_params=spline_params,
        postprocessing="partial_mlp",
        postprocessing_layers=linlayers,
        postprocessing_channel_factor=linchannelfactor,
        use_actnorm=actnorm,
        use_batchnorm=batchnorm,
    )
    inner_transform = create_vector_transform(
        latentdim,
        innerlayers,
        linear_transform_type=lineartransform,
        base_transform_type="rq-coupling",
        context_features=contextfeatures,
        dropout_probability=dropout,
        tail_bound=splinerange,
        num_bins=splinebins,
        use_batch_norm=batchnorm,
    )
    model = ManifoldFlow(
        data_dim=(3, 64, 64),
        latent_dim=latentdim,
        outer_transform=outer_transform,
        inner_transform=inner_transform,
        apply_context_to_outer=False,
        pie_epsilon=0.1,
        clip_pie=None
    )
        
    model.load_state_dict(
        torch.load("../data/models/{}.pt".format(filename), map_location=torch.device("cpu"))
    )
    _ = model.eval()
    
    return model

# %%
mf2 = load_model("mf_2_gan2d_april")
mf64 = load_model("mf_64_gan64d_april", innerlayers=8, linchannelfactor=2, latentdim=64, contextfeatures=1)
mfc = load_model("emf_128_celeba_april", innerlayers=8, linchannelfactor=2, latentdim=128)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-f5f486d9050c> in <module>
#       1 mf2 = load_model("mf_2_gan2d_april")
#       2 mf64 = load_model("mf_64_gan64d_april", innerlayers=8, linchannelfactor=2, latentdim=64, contextfeatures=1)
# ----> 3 mfc = load_model("emf_128_celeba_april", innerlayers=8, linchannelfactor=2, latentdim=128)
#
# <ipython-input-2-3d0e1a96c799> in load_model(filename, latentdim, outerlayers, innerlayers, levels, splinebins, splinerange, dropout, actnorm, batchnorm, contextfeatures, linlayers, linchannelfactor, lineartransform)
#      66
#      67     model.load_state_dict(
# ---> 68         torch.load("../data/models/{}.pt".format(filename), map_location=torch.device("cpu"))
#      69     )
#      70     _ = model.eval()
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     845         if len(error_msgs) > 0:
#     846             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 847                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     848         return _IncompatibleKeys(missing_keys, unexpected_keys)
#     849
#
# RuntimeError: Error(s) in loading state_dict for ManifoldFlow:
# 	Unexpected key(s) in state_dict: "encoder.encoder.initial_layer.weight", "encoder.encoder.initial_layer.bias", "encoder.encoder.residual_blocks.0.residual_layer_1.weight", "encoder.encoder.residual_blocks.0.residual_layer_1.bias", "encoder.encoder.residual_blocks.0.residual_2_layer.weight", "encoder.encoder.residual_blocks.0.residual_2_layer.bias", "encoder.encoder.residual_blocks.1.residual_layer_1.weight", "encoder.encoder.residual_blocks.1.residual_layer_1.bias", "encoder.encoder.residual_blocks.1.shortcut_layer.weight", "encoder.encoder.residual_blocks.1.shortcut_layer.bias", "encoder.encoder.residual_blocks.1.residual_2_layer.weight", "encoder.encoder.residual_blocks.1.residual_2_layer.bias", "encoder.encoder.residual_blocks.2.residual_layer_1.weight", "encoder.encoder.residual_blocks.2.residual_layer_1.bias", "encoder.encoder.residual_blocks.2.residual_2_layer.weight", "encoder.encoder.residual_blocks.2.residual_2_layer.bias", "encoder.encoder.residual_blocks.3.residual_layer_1.weight", "encoder.encoder.residual_blocks.3.residual_layer_1.bias", "encoder.encoder.residual_blocks.3.shortcut_layer.weight", "encoder.encoder.residual_blocks.3.shortcut_layer.bias", "encoder.encoder.residual_blocks.3.residual_2_layer.weight", "encoder.encoder.residual_blocks.3.residual_2_layer.bias", "encoder.encoder.residual_blocks.4.residual_layer_1.weight", "encoder.encoder.residual_blocks.4.residual_layer_1.bias", "encoder.encoder.residual_blocks.4.residual_2_layer.weight", "encoder.encoder.residual_blocks.4.residual_2_layer.bias", "encoder.encoder.residual_blocks.5.residual_layer_1.weight", "encoder.encoder.residual_blocks.5.residual_layer_1.bias", "encoder.encoder.residual_blocks.5.shortcut_layer.weight", "encoder.encoder.residual_blocks.5.shortcut_layer.bias", "encoder.encoder.residual_blocks.5.residual_2_layer.weight", "encoder.encoder.residual_blocks.5.residual_2_layer.bias", "encoder.encoder.residual_blocks.6.residual_layer_1.weight", "encoder.encoder.residual_blocks.6.residual_layer_1.bias", "encoder.encoder.residual_blocks.6.residual_2_layer.weight", "encoder.encoder.residual_blocks.6.residual_2_layer.bias", "encoder.encoder.residual_blocks.7.residual_layer_1.weight", "encoder.encoder.residual_blocks.7.residual_layer_1.bias", "encoder.encoder.residual_blocks.7.shortcut_layer.weight", "encoder.encoder.residual_blocks.7.shortcut_layer.bias", "encoder.encoder.residual_blocks.7.residual_2_layer.weight", "encoder.encoder.residual_blocks.7.residual_2_layer.bias", "encoder.encoder.final_layer.weight", "encoder.encoder.final_layer.bias", "encoder.preprocessor._shift", "encoder.preprocessor._scale".

# %% [markdown]
# ## Master functions

# %%
def spline_tour(model, z_checkpoints, filename, n_frames=200, fps=25, context=None):
    z_checkpoints = np.concatenate((z_checkpoints, z_checkpoints[0:1]), axis=0)
    tck, u = interpolate.splprep(z_checkpoints.T, s=0, per=True)
    z_frames = np.array(interpolate.splev(np.linspace(0, 1, n_frames), tck)).T
    
    ims = []
    for z in z_frames:
        x = model.decode(torch.tensor(z).to(torch.float).unsqueeze(0), context=None if context is None else context.unsqueeze(0)).squeeze().detach().numpy()
        x = np.transpose(x, [1,2,0])
        ims.append(x)
    
    imageio.mimsave(filename, ims, 'GIF-FI', duration=1.0/fps)

# %%
def linear_interpolator(inputs, n_frames):
    n_inputs = len(inputs)
    inputs_ = np.concatenate((inputs, inputs[0:1]), axis=0)
    t_frames = np.linspace(0.0, float(n_inputs), n_frames+1)[:-1]
    
    last = np.floor(t_frames).astype(np.int)
    next_ = np.ceil(t_frames).astype(np.int)
    alpha = t_frames - last.astype(np.float)
    
    outputs = (1. - alpha[:,np.newaxis]) * inputs_[last] + alpha[:,np.newaxis] * inputs_[next_]
    
    return outputs
    

def linear_tour(model, z_checkpoints, filename, n_frames=200, fps=25, context=None):
    z_frames = linear_interpolator(z_checkpoints, n_frames)
    
    ims = []
    for z in z_frames:
        x = model.decode(torch.tensor(z).to(torch.float).unsqueeze(0), context=None if context is None else context.unsqueeze(0)).squeeze().detach().numpy()
        x = np.transpose(x, [1,2,0])
        ims.append(x)
    
    imageio.mimsave(filename, ims, 'GIF-FI', duration=1.0/fps)

# %% [markdown]
# ## n=2 circle tour

# %%
n_frames = 200

ts = np.linspace(0., 2. * np.pi, n_frames + 1)[:-1]
zs = np.vstack((np.cos(ts), np.sin(ts))).T

spline_tour(mf2, zs, n_frames=n_frames, filename="../figures/gan2d_tour_circle_mf.gif")

# %% [markdown]
# ## CelebA tour from a real image

# %%
x_reals = np.array([
    plt.imread("../data/samples/celeba/test/25.jpg"),
    plt.imread("../data/samples/celeba/test/30.jpg"),
    plt.imread("../data/samples/celeba/test/53.jpg"),
    plt.imread("../data/samples/celeba/test/49.jpg"),
    plt.imread("../data/samples/celeba/test/52.jpg"),
])
x_reals_ = torch.tensor(x_reals.transpose(0,3,1,2)).to(torch.float)
z_reals = mfc.encode(x_reals_).detach().numpy()

# %%
z_tour = np.array(z_reals)

# %%
linear_tour(mfc, z_tour, n_frames=200, filename="../figures/celeba_tour_test_emf.gif")
# Out:
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [-1.8966217041015625, 244.052490234375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0.472137451171875, 241.5618896484375]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.1876983642578125, 238.80209350585938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [3.5947494506835938, 236.21511840820312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [4.4076385498046875, 233.82473754882812]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [5.584785461425781, 232.32058715820312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [7.001792907714844, 231.35482788085938]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.232223510742188, 230.5017852783203]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [9.189422607421875, 229.60281372070312]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [9.594680786132812, 228.23849487304688]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [9.37939453125, 226.5624542236328]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.713737487792969, 225.35211181640625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.166641235351562, 223.73287963867188]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.093124389648438, 222.1913604736328]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.112968444824219, 221.04498291015625]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.055389404296875, 220.48472595214844]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [7.910606384277344, 220.2313232421875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [7.776824951171875, 220.0771942138672]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.103431701660156, 220.23355102539062]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [8.52056884765625, 220.39520263671875]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [9